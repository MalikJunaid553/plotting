# %%
import matplotlib.pyplot as plt

# %%
data =[2,3,4,5,6,3,4,5,2,1,4,9]

# %%
plt.plot(data)
plt.show()

# %%
plt.title("Line Plot")
plt.xlabel("Age")
plt.ylabel("People")
plt.plot(data)
plt.show()
